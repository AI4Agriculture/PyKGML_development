# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
from io import open
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import Dataset, DataLoader
import time
# from scipy.stats import gaussian_kde
# import scipy.stats as stats

# %%
# To import dataset and time_series_models succesful,
# here need to set correct path
import sys
import os
current_dir = os.path.dirname(os.path.abspath(''))
parent_dir = os.path.dirname(current_dir)

# here add current path. Please check the value of current_dir and parent_dir
sys.path.append(current_dir)

# %%
from dataset import CO2_fluxtower_dataset 
from time_series_models import GRUSeq2SeqWithAttention, TimeSeriesModel, SequenceDataset

# %%
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import kgml_lib
Z_norm_reverse = kgml_lib.Z_norm_reverse
Z_norm_with_scaler = kgml_lib.Z_norm_with_scaler

# %%
root_dir = 'E:/PyKGML/deposit_code_v2/'
data_path = root_dir +  'processed_data/'
output_path = root_dir + 'test_results/'

#input_data = 'recotest_data_scaled_v4_100sample.sav'
#sample_index_file = "flux_split_year_v1.sav"

pretrained_model = "recotest_v11_exp4.sav_step4"
output_model = "recotest_v11_exp4_sample.sav_step5"
synthetic_data = "sys_data10.sav"

dataset = CO2_fluxtower_dataset(data_path, output_path)
dataset.load_scaler_data('recotest_data_scaled_v4_scalers.sav')
dataset.load_fluxtower_inputs_data('fluxtower_inputs_noscale_v2.sav')
dataset.load_fluxtower_observe_data('fluxtower_observe_noscale_v2.sav')

dataset.prepare_data('flux_split_year_v1.sav')
# Out:
# torch.Size([3285]) torch.Size([1, 3285, 19])
# torch.Size([1825]) torch.Size([1, 1825, 19])
# torch.Size([2555]) torch.Size([1, 2555, 19])
# torch.Size([2555]) torch.Size([1, 2555, 19])
# torch.Size([5110]) torch.Size([1, 5110, 19])
# torch.Size([3650]) torch.Size([1, 3650, 19])
# torch.Size([6935]) torch.Size([1, 6935, 19])
# torch.Size([6935]) torch.Size([1, 6935, 19])
# torch.Size([6935]) torch.Size([1, 6935, 19])
# torch.Size([4015]) torch.Size([1, 4015, 19])
# torch.Size([1460]) torch.Size([1, 1460, 19])

# %%
# Calculate Y1 and Y2  mean and std value
y1 = dataset.Y_NEE_obs
y2 = dataset.Y_Reco_obs

y1_NEE = torch.cat(y1).cpu().numpy()
y2_Reco = torch.cat(y2).cpu().numpy()

y1_NEE = y1_NEE.astype(np.float32)
y2_Reco = y2_Reco.astype(np.float32)

y1_NEE_scaler = [np.mean(y1_NEE), np.std(y1_NEE)]
y2_Reco_scaler = [np.mean(y2_Reco), np.std(y2_Reco)]

# %%
y_scaler = np.array([y1_NEE_scaler,y2_Reco_scaler])
y_scaler
# Out:
# array([[-0.6805228,  3.8309526],
#        [ 2.769683 ,  3.0988922]], dtype=float32)

# %%
# Split train and test dataset
# 11 sites, choose each site's last two years for test

x = dataset.X_sites
y1 = dataset.Y_NEE_obs
y2 = dataset.Y_Reco_obs

test_days = 365*2 # 2 years 

train_X_list = []
test_X_list = []
train_Y_list = []
test_Y_list = []

for i in range(len(x)):
    train_x = x[i][:,:-test_days,:]
    test_x = x[i][:,-test_days:,:]
    train_X_list.append(train_x)
    test_X_list.append(test_x)

    # _y1 = y1[i].unsqueeze(1)
    _y1 = Z_norm_with_scaler(y1[i].type(torch.float32), y1_NEE_scaler).unsqueeze(1)
    # _y2 = y2[i].unsqueeze(1)
    _y2 = Z_norm_with_scaler(y2[i].type(torch.float32), y2_Reco_scaler).unsqueeze(1)
    _y = torch.cat((_y1,_y2), dim=1)

    train_y = _y[:-test_days,:]
    test_y  = _y[-test_days:,:]
    train_Y_list.append(train_y)
    test_Y_list.append(test_y)

X_train = torch.cat(train_X_list, dim=1)
X_test  = torch.cat(test_X_list,  dim=1)

Y_train = torch.cat(train_Y_list, dim=0)
Y_train = Y_train.unsqueeze(0) 
Y_test  = torch.cat(test_Y_list,  dim=0)
Y_test = Y_test.unsqueeze(0)

# %%
Y_train.shape, X_train.shape
# Out:
# (torch.Size([1, 37230, 2]), torch.Size([1, 37230, 19]))

# %% [raw]
# co2_finetune_file = data_path + 'co2_finetune_data.sav'
# torch.save({'X_train': X_train,
#             'X_test': X_test,
#             'Y_train': Y_train,
#             'Y_test': Y_test,
#             'y_scaler': y_scaler}, co2_finetune_file)

# %%
# Set parameters for create a Module
num_input_features = 19
num_output_features = 2

input_dim = num_input_features
hidden_dim = 128
num_layers = 3
output_dim = num_output_features
dropout=0.2

# %%
# Choose one of the models below:
#model = LSTMSeq2Seq(input_dim, hidden_dim, num_layers, output_dim)
# model = GRUSeq2Seq(input_dim, hidden_dim, num_layers, output_dim)

# model = EnhancedGRUModel(input_dim, hidden_dim, num_layers, output_dim)

model = GRUSeq2SeqWithAttention(input_dim, hidden_dim, num_layers, output_dim, dropout)

# %%
# Create Pytorch dataloader
sequence_length = 365  # Use 365 consecutive days as a sample

# Create Dataset objects for training and testing.
train_dataset = SequenceDataset(X_train, Y_train, sequence_length)
test_dataset = SequenceDataset(X_test, Y_test, sequence_length)

# Create DataLoaders.
batch_size = 64
model.train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
model.test_loader  = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
learning_rate = 0.001
step_size = 40
max_epoch = 200
gamma = 0.8
loss_function = nn.L1Loss() # nn.MSELoss()

# model.train_model(train_loader, test_loader, LR= learning_rate, step_size=20, gamma=0.8, maxepoch=60)
model.train_model(loss_fun=loss_function, LR= learning_rate, step_size= step_size, gamma=0.8, maxepoch=max_epoch)
# Out:
# Epoch 1/200 | LR: 0.001000, Train Loss: 0.6887, Test Loss: 0.5839
# Epoch 2/200 | LR: 0.001000, Train Loss: 0.5881, Test Loss: 0.5193
# Epoch 3/200 | LR: 0.001000, Train Loss: 0.5281, Test Loss: 0.4706
# Epoch 4/200 | LR: 0.001000, Train Loss: 0.4638, Test Loss: 0.4257
# Epoch 5/200 | LR: 0.001000, Train Loss: 0.4045, Test Loss: 0.4025
# Epoch 39/200 | LR: 0.001000, Train Loss: 0.1823, Test Loss: 0.1987
# Epoch 40/200 | LR: 0.000800, Train Loss: 0.1812, Test Loss: 0.1982
# Epoch 41/200 | LR: 0.000800, Train Loss: 0.1783, Test Loss: 0.1966
# Epoch 42/200 | LR: 0.000800, Train Loss: 0.1786, Test Loss: 0.1961
# Epoch 43/200 | LR: 0.000800, Train Loss: 0.1767, Test Loss: 0.1967
# Epoch 44/200 | LR: 0.000800, Train Loss: 0.1751, Test Loss: 0.1940
# Epoch 45/200 | LR: 0.000800, Train Loss: 0.1765, Test Loss: 0.1947
# Epoch 46/200 | LR: 0.000800, Train Loss: 0.1747, Test Loss: 0.1928
# Epoch 47/200 | LR: 0.000800, Train Loss: 0.1734, Test Loss: 0.1943
# Epoch 48/200 | LR: 0.000800, Train Loss: 0.1708, Test Loss: 0.1932
# Epoch 49/200 | LR: 0.000800, Train Loss: 0.1708, Test Loss: 0.1944
# Epoch 50/200 | LR: 0.000800, Train Loss: 0.1692, Test Loss: 0.1909
# Epoch 51/200 | LR: 0.000800, Train Loss: 0.1704, Test Loss: 0.1931
# Epoch 52/200 | LR: 0.000800, Train Loss: 0.1674, Test Loss: 0.1892
# Epoch 53/200 | LR: 0.000800, Train Loss: 0.1683, Test Loss: 0.1884
# Epoch 54/200 | LR: 0.000800, Train Loss: 0.1668, Test Loss: 0.1878
# Epoch 55/200 | LR: 0.000800, Train Loss: 0.1659, Test Loss: 0.1905
# Epoch 56/200 | LR: 0.000800, Train Loss: 0.1640, Test Loss: 0.1890
# Epoch 57/200 | LR: 0.000800, Train Loss: 0.1617, Test Loss: 0.1878
# Epoch 58/200 | LR: 0.000800, Train Loss: 0.1663, Test Loss: 0.1882
# Epoch 59/200 | LR: 0.000800, Train Loss: 0.1617, Test Loss: 0.1873
# Epoch 60/200 | LR: 0.000800, Train Loss: 0.1615, Test Loss: 0.1864
# Epoch 61/200 | LR: 0.000800, Train Loss: 0.1621, Test Loss: 0.1851
# Epoch 62/200 | LR: 0.000800, Train Loss: 0.1652, Test Loss: 0.1894
# Epoch 63/200 | LR: 0.000800, Train Loss: 0.1618, Test Loss: 0.1859
# Epoch 64/200 | LR: 0.000800, Train Loss: 0.1598, Test Loss: 0.1891
# Epoch 65/200 | LR: 0.000800, Train Loss: 0.1592, Test Loss: 0.1852
# Epoch 66/200 | LR: 0.000800, Train Loss: 0.1571, Test Loss: 0.1895
# Epoch 67/200 | LR: 0.000800, Train Loss: 0.1557, Test Loss: 0.1844
# Epoch 68/200 | LR: 0.000800, Train Loss: 0.1574, Test Loss: 0.1874
# Epoch 69/200 | LR: 0.000800, Train Loss: 0.1587, Test Loss: 0.1830
# Epoch 70/200 | LR: 0.000800, Train Loss: 0.1590, Test Loss: 0.1897
# Epoch 71/200 | LR: 0.000800, Train Loss: 0.1588, Test Loss: 0.1837
# Epoch 72/200 | LR: 0.000800, Train Loss: 0.1551, Test Loss: 0.1852
# Epoch 73/200 | LR: 0.000800, Train Loss: 0.1572, Test Loss: 0.1835
# Epoch 74/200 | LR: 0.000800, Train Loss: 0.1569, Test Loss: 0.1840
# Epoch 75/200 | LR: 0.000800, Train Loss: 0.1548, Test Loss: 0.1819
# Epoch 76/200 | LR: 0.000800, Train Loss: 0.1525, Test Loss: 0.1835
# Epoch 77/200 | LR: 0.000800, Train Loss: 0.1558, Test Loss: 0.1806
# Epoch 78/200 | LR: 0.000800, Train Loss: 0.1518, Test Loss: 0.1804
# Epoch 79/200 | LR: 0.000800, Train Loss: 0.1504, Test Loss: 0.1846
# Epoch 80/200 | LR: 0.000640, Train Loss: 0.1549, Test Loss: 0.1839
# Epoch 81/200 | LR: 0.000640, Train Loss: 0.1541, Test Loss: 0.1818
# Epoch 82/200 | LR: 0.000640, Train Loss: 0.1496, Test Loss: 0.1823
# Epoch 83/200 | LR: 0.000640, Train Loss: 0.1500, Test Loss: 0.1812
# Epoch 84/200 | LR: 0.000640, Train Loss: 0.1509, Test Loss: 0.1819
# Epoch 85/200 | LR: 0.000640, Train Loss: 0.1477, Test Loss: 0.1816
# Epoch 86/200 | LR: 0.000640, Train Loss: 0.1487, Test Loss: 0.1817
# Epoch 87/200 | LR: 0.000640, Train Loss: 0.1485, Test Loss: 0.1805
# Epoch 88/200 | LR: 0.000640, Train Loss: 0.1506, Test Loss: 0.1835
# Epoch 89/200 | LR: 0.000640, Train Loss: 0.1497, Test Loss: 0.1813
# Epoch 90/200 | LR: 0.000640, Train Loss: 0.1455, Test Loss: 0.1815
# Epoch 91/200 | LR: 0.000640, Train Loss: 0.1453, Test Loss: 0.1823
# Epoch 92/200 | LR: 0.000640, Train Loss: 0.1503, Test Loss: 0.1808
# Epoch 93/200 | LR: 0.000640, Train Loss: 0.1456, Test Loss: 0.1827
# Epoch 94/200 | LR: 0.000640, Train Loss: 0.1458, Test Loss: 0.1830
# Epoch 95/200 | LR: 0.000640, Train Loss: 0.1459, Test Loss: 0.1829
# Epoch 96/200 | LR: 0.000640, Train Loss: 0.1449, Test Loss: 0.1828
# Epoch 97/200 | LR: 0.000640, Train Loss: 0.1459, Test Loss: 0.1818
#
# #***# Early stopping triggered after 98 epochs!

# %%
model.test()
# Out:
# Test Loss: 0.1804

# %%
model.plot_training_curves()

# %%
output_feature_name = ['NEE','RECO']
model.get_R2_score(y_scaler, output_feature_name)
# Out:
# Feature NEE R2 Score is: 0.9272819888105184
# Feature RECO R2 Score is: 0.8722945067838274

# %%
model.Vis_plot_prediction_result_time_series(y_scaler, output_feature_name, site=0, year=0)

# %%
model.Vis_scatter_prediction_result(y_scaler, output_feature_name)
