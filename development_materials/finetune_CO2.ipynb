# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
from io import open
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import Dataset, DataLoader
import time
# from scipy.stats import gaussian_kde
# import scipy.stats as stats

# %%
from dataset import Step5_DataSet
from time_series_models import GRUSeq2SeqWithAttention, TimeSeriesModel, SequenceDataset

# %%
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import kgml_lib
Z_norm_reverse = kgml_lib.Z_norm_reverse
Z_norm_with_scaler = kgml_lib.Z_norm_with_scaler

# %%
root_dir = 'E:/PyKGML/deposit_code_v2/'
data_path = root_dir +  'processed_data/'
output_path = root_dir + 'test_results/'

#input_data = 'recotest_data_scaled_v4_100sample.sav'
#sample_index_file = "flux_split_year_v1.sav"

pretrained_model = "recotest_v11_exp4.sav_step4"
output_model = "recotest_v11_exp4_sample.sav_step5"
synthetic_data = "sys_data10.sav"

dataset = Step5_DataSet(data_path, output_path)
dataset.load_scaler_data('recotest_data_scaled_v4_scalers.sav')
dataset.load_fluxtower_inputs_data('fluxtower_inputs_noscale_v2.sav')
dataset.load_fluxtower_observe_data('fluxtower_observe_noscale_v2.sav')

dataset.prepare_data('flux_split_year_v1.sav')
# Out:
# torch.Size([3285]) torch.Size([1, 3285, 19])
# torch.Size([1825]) torch.Size([1, 1825, 19])
# torch.Size([2555]) torch.Size([1, 2555, 19])
# torch.Size([2555]) torch.Size([1, 2555, 19])
# torch.Size([5110]) torch.Size([1, 5110, 19])
# torch.Size([3650]) torch.Size([1, 3650, 19])
# torch.Size([6935]) torch.Size([1, 6935, 19])
# torch.Size([6935]) torch.Size([1, 6935, 19])
# torch.Size([6935]) torch.Size([1, 6935, 19])
# torch.Size([4015]) torch.Size([1, 4015, 19])
# torch.Size([1460]) torch.Size([1, 1460, 19])

# %%
# Calculate Y1 and Y2  mean and std value
y1 = dataset.Y_NEE_obs
y2 = dataset.Y_Reco_obs

y1_NEE = torch.cat(y1).cpu().numpy()
y2_Reco = torch.cat(y2).cpu().numpy()

y1_NEE = y1_NEE.astype(np.float32)
y2_Reco = y2_Reco.astype(np.float32)

y1_NEE_scaler = [np.mean(y1_NEE), np.std(y1_NEE)]
y2_Reco_scaler = [np.mean(y2_Reco), np.std(y2_Reco)]

# %%
y_scaler = np.array([y1_NEE_scaler,y2_Reco_scaler])
y_scaler
# Out:
# array([[-0.6805228,  3.8309526],
#        [ 2.769683 ,  3.0988922]], dtype=float32)

# %%
# Split train and test dataset
# 11 sites, choose each site's last two years for test

x = dataset.X_sites
y1 = dataset.Y_NEE_obs
y2 = dataset.Y_Reco_obs

test_days = 365*2 # 2 years 

train_X_list = []
test_X_list = []
train_Y_list = []
test_Y_list = []

for i in range(len(x)):
    train_x = x[i][:,:-test_days,:]
    test_x = x[i][:,-test_days:,:]
    train_X_list.append(train_x)
    test_X_list.append(test_x)

    # _y1 = y1[i].unsqueeze(1)
    _y1 = Z_norm_with_scaler(y1[i].type(torch.float32), y1_NEE_scaler).unsqueeze(1)
    # _y2 = y2[i].unsqueeze(1)
    _y2 = Z_norm_with_scaler(y2[i].type(torch.float32), y2_Reco_scaler).unsqueeze(1)
    _y = torch.cat((_y1,_y2), dim=1)

    train_y = _y[:-test_days,:]
    test_y  = _y[-test_days:,:]
    train_Y_list.append(train_y)
    test_Y_list.append(test_y)

X_train = torch.cat(train_X_list, dim=1)
X_test  = torch.cat(test_X_list,  dim=1)

Y_train = torch.cat(train_Y_list, dim=0)
Y_train = Y_train.unsqueeze(0) 
Y_test  = torch.cat(test_Y_list,  dim=0)
Y_test = Y_test.unsqueeze(0)

# %%
Y_train.shape, X_train.shape
# Out:
# (torch.Size([1, 37230, 2]), torch.Size([1, 37230, 19]))

# %%
co2_finetune_file = data_path + 'co2_finetune_data.sav'
torch.save({'X_train': X_train,
            'X_test': X_test,
            'Y_train': Y_train,
            'Y_test': Y_test,
            'y_scaler': y_scaler}, co2_finetune_file)

# %%
# Set parameters for create a Module
num_input_features = 19
num_output_features = 2

input_dim = num_input_features
hidden_dim = 128
num_layers = 3
output_dim = num_output_features
dropout=0.2

# %%
# Choose one of the models below:
#model = LSTMSeq2Seq(input_dim, hidden_dim, num_layers, output_dim)
# model = GRUSeq2Seq(input_dim, hidden_dim, num_layers, output_dim)

# model = EnhancedGRUModel(input_dim, hidden_dim, num_layers, output_dim)

model = GRUSeq2SeqWithAttention(input_dim, hidden_dim, num_layers, output_dim, dropout)

# %%
# Create Pytorch dataloader
sequence_length = 365  # Use 365 consecutive days as a sample

# Create Dataset objects for training and testing.
train_dataset = SequenceDataset(X_train, Y_train, sequence_length)
test_dataset = SequenceDataset(X_test, Y_test, sequence_length)

# Create DataLoaders.
batch_size = 64
model.train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
model.test_loader  = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
learning_rate = 0.001
step_size = 40
max_epoch = 200
gamma = 0.8
loss_function = nn.L1Loss() # nn.MSELoss()

# model.train_model(train_loader, test_loader, LR= learning_rate, step_size=20, gamma=0.8, maxepoch=60)
model.train_model(loss_fun=loss_function, LR= learning_rate, step_size= step_size, gamma=0.8, maxepoch=max_epoch)
# Out:
# Epoch 1/200 | LR: 0.001000, Train Loss: 0.6954, Test Loss: 0.5913
# Epoch 2/200 | LR: 0.001000, Train Loss: 0.5736, Test Loss: 0.5043
# Epoch 3/200 | LR: 0.001000, Train Loss: 0.5126, Test Loss: 0.4712
# Epoch 4/200 | LR: 0.001000, Train Loss: 0.4703, Test Loss: 0.4337
# Epoch 5/200 | LR: 0.001000, Train Loss: 0.4198, Test Loss: 0.3956
# Epoch 6/200 | LR: 0.001000, Train Loss: 0.3864, Test Loss: 0.3553
# Epoch 7/200 | LR: 0.001000, Train Loss: 0.3411, Test Loss: 0.3275
# Epoch 8/200 | LR: 0.001000, Train Loss: 0.3202, Test Loss: 0.3208
# Epoch 9/200 | LR: 0.001000, Train Loss: 0.3064, Test Loss: 0.3159
# Epoch 10/200 | LR: 0.001000, Train Loss: 0.2888, Test Loss: 0.2973
# Epoch 11/200 | LR: 0.001000, Train Loss: 0.2740, Test Loss: 0.2892
# Epoch 12/200 | LR: 0.001000, Train Loss: 0.2667, Test Loss: 0.2966
# Epoch 13/200 | LR: 0.001000, Train Loss: 0.2658, Test Loss: 0.2875
# Epoch 14/200 | LR: 0.001000, Train Loss: 0.2535, Test Loss: 0.2832
# Epoch 15/200 | LR: 0.001000, Train Loss: 0.2502, Test Loss: 0.2826
# Epoch 16/200 | LR: 0.001000, Train Loss: 0.2462, Test Loss: 0.2752
# Epoch 17/200 | LR: 0.001000, Train Loss: 0.2422, Test Loss: 0.2663
# Epoch 18/200 | LR: 0.001000, Train Loss: 0.2387, Test Loss: 0.2596
# Epoch 19/200 | LR: 0.001000, Train Loss: 0.2314, Test Loss: 0.2573
# Epoch 20/200 | LR: 0.001000, Train Loss: 0.2305, Test Loss: 0.2536
# Epoch 21/200 | LR: 0.001000, Train Loss: 0.2346, Test Loss: 0.2520
# Epoch 22/200 | LR: 0.001000, Train Loss: 0.2281, Test Loss: 0.2510
# Epoch 23/200 | LR: 0.001000, Train Loss: 0.2239, Test Loss: 0.2487
# Epoch 24/200 | LR: 0.001000, Train Loss: 0.2235, Test Loss: 0.2447
# Epoch 25/200 | LR: 0.001000, Train Loss: 0.2195, Test Loss: 0.2420
# Epoch 26/200 | LR: 0.001000, Train Loss: 0.2202, Test Loss: 0.2397
# Epoch 27/200 | LR: 0.001000, Train Loss: 0.2174, Test Loss: 0.2381
# Epoch 28/200 | LR: 0.001000, Train Loss: 0.2164, Test Loss: 0.2356
# Epoch 29/200 | LR: 0.001000, Train Loss: 0.2138, Test Loss: 0.2330
# Epoch 30/200 | LR: 0.001000, Train Loss: 0.2080, Test Loss: 0.2293
# Epoch 31/200 | LR: 0.001000, Train Loss: 0.2071, Test Loss: 0.2259
# Epoch 32/200 | LR: 0.001000, Train Loss: 0.2030, Test Loss: 0.2231
# Epoch 33/200 | LR: 0.001000, Train Loss: 0.2022, Test Loss: 0.2195
# Epoch 34/200 | LR: 0.001000, Train Loss: 0.1988, Test Loss: 0.2163
# Epoch 35/200 | LR: 0.001000, Train Loss: 0.1938, Test Loss: 0.2123
# Epoch 36/200 | LR: 0.001000, Train Loss: 0.1925, Test Loss: 0.2094
# Epoch 37/200 | LR: 0.001000, Train Loss: 0.1907, Test Loss: 0.2051
# Epoch 38/200 | LR: 0.001000, Train Loss: 0.1903, Test Loss: 0.2021
# Epoch 39/200 | LR: 0.001000, Train Loss: 0.1851, Test Loss: 0.1993
# Epoch 40/200 | LR: 0.000800, Train Loss: 0.1830, Test Loss: 0.1978
# Epoch 41/200 | LR: 0.000800, Train Loss: 0.1789, Test Loss: 0.1958
# Epoch 42/200 | LR: 0.000800, Train Loss: 0.1800, Test Loss: 0.1952
# Epoch 43/200 | LR: 0.000800, Train Loss: 0.1790, Test Loss: 0.1955
# Epoch 44/200 | LR: 0.000800, Train Loss: 0.1780, Test Loss: 0.1944
# Epoch 45/200 | LR: 0.000800, Train Loss: 0.1754, Test Loss: 0.1949
# Epoch 46/200 | LR: 0.000800, Train Loss: 0.1737, Test Loss: 0.1927
# Epoch 47/200 | LR: 0.000800, Train Loss: 0.1713, Test Loss: 0.1927
# Epoch 48/200 | LR: 0.000800, Train Loss: 0.1720, Test Loss: 0.1935
# Epoch 49/200 | LR: 0.000800, Train Loss: 0.1688, Test Loss: 0.1913
# Epoch 50/200 | LR: 0.000800, Train Loss: 0.1733, Test Loss: 0.1933
# Epoch 51/200 | LR: 0.000800, Train Loss: 0.1736, Test Loss: 0.1889
# Epoch 52/200 | LR: 0.000800, Train Loss: 0.1693, Test Loss: 0.1897
# Epoch 53/200 | LR: 0.000800, Train Loss: 0.1658, Test Loss: 0.1885
# Epoch 54/200 | LR: 0.000800, Train Loss: 0.1690, Test Loss: 0.1905
# Epoch 55/200 | LR: 0.000800, Train Loss: 0.1668, Test Loss: 0.1882
# Epoch 56/200 | LR: 0.000800, Train Loss: 0.1650, Test Loss: 0.1877
# Epoch 57/200 | LR: 0.000800, Train Loss: 0.1657, Test Loss: 0.1883
# Epoch 58/200 | LR: 0.000800, Train Loss: 0.1655, Test Loss: 0.1861
# Epoch 59/200 | LR: 0.000800, Train Loss: 0.1622, Test Loss: 0.1855
# Epoch 60/200 | LR: 0.000800, Train Loss: 0.1603, Test Loss: 0.1870
# Epoch 61/200 | LR: 0.000800, Train Loss: 0.1595, Test Loss: 0.1860
# Epoch 62/200 | LR: 0.000800, Train Loss: 0.1610, Test Loss: 0.1865
# Epoch 63/200 | LR: 0.000800, Train Loss: 0.1609, Test Loss: 0.1850
# Epoch 64/200 | LR: 0.000800, Train Loss: 0.1617, Test Loss: 0.1846
# Epoch 65/200 | LR: 0.000800, Train Loss: 0.1594, Test Loss: 0.1841
# Epoch 66/200 | LR: 0.000800, Train Loss: 0.1627, Test Loss: 0.1860
# Epoch 67/200 | LR: 0.000800, Train Loss: 0.1576, Test Loss: 0.1854
# Epoch 68/200 | LR: 0.000800, Train Loss: 0.1593, Test Loss: 0.1864
# Epoch 69/200 | LR: 0.000800, Train Loss: 0.1567, Test Loss: 0.1839
# Epoch 70/200 | LR: 0.000800, Train Loss: 0.1567, Test Loss: 0.1850
# Epoch 71/200 | LR: 0.000800, Train Loss: 0.1583, Test Loss: 0.1853
# Epoch 72/200 | LR: 0.000800, Train Loss: 0.1518, Test Loss: 0.1865
# Epoch 73/200 | LR: 0.000800, Train Loss: 0.1530, Test Loss: 0.1858
# Epoch 74/200 | LR: 0.000800, Train Loss: 0.1544, Test Loss: 0.1867
# Epoch 75/200 | LR: 0.000800, Train Loss: 0.1518, Test Loss: 0.1803
# Epoch 76/200 | LR: 0.000800, Train Loss: 0.1550, Test Loss: 0.1847
# Epoch 77/200 | LR: 0.000800, Train Loss: 0.1514, Test Loss: 0.1819
# Epoch 78/200 | LR: 0.000800, Train Loss: 0.1529, Test Loss: 0.1868
# Epoch 79/200 | LR: 0.000800, Train Loss: 0.1525, Test Loss: 0.1866
# Epoch 80/200 | LR: 0.000640, Train Loss: 0.1521, Test Loss: 0.1848
# Epoch 81/200 | LR: 0.000640, Train Loss: 0.1526, Test Loss: 0.1789
# Epoch 82/200 | LR: 0.000640, Train Loss: 0.1536, Test Loss: 0.1814
# Epoch 83/200 | LR: 0.000640, Train Loss: 0.1475, Test Loss: 0.1790
# Epoch 84/200 | LR: 0.000640, Train Loss: 0.1473, Test Loss: 0.1828
# Epoch 85/200 | LR: 0.000640, Train Loss: 0.1492, Test Loss: 0.1854
# Epoch 86/200 | LR: 0.000640, Train Loss: 0.1460, Test Loss: 0.1834
# Epoch 87/200 | LR: 0.000640, Train Loss: 0.1480, Test Loss: 0.1803
# Epoch 88/200 | LR: 0.000640, Train Loss: 0.1472, Test Loss: 0.1795
# Epoch 89/200 | LR: 0.000640, Train Loss: 0.1471, Test Loss: 0.1817
# Epoch 90/200 | LR: 0.000640, Train Loss: 0.1451, Test Loss: 0.1827
# Epoch 91/200 | LR: 0.000640, Train Loss: 0.1441, Test Loss: 0.1818
# Epoch 92/200 | LR: 0.000640, Train Loss: 0.1413, Test Loss: 0.1822
# Epoch 93/200 | LR: 0.000640, Train Loss: 0.1430, Test Loss: 0.1802
# Epoch 94/200 | LR: 0.000640, Train Loss: 0.1451, Test Loss: 0.1829
# Epoch 95/200 | LR: 0.000640, Train Loss: 0.1453, Test Loss: 0.1813
# Epoch 96/200 | LR: 0.000640, Train Loss: 0.1445, Test Loss: 0.1861
# Epoch 97/200 | LR: 0.000640, Train Loss: 0.1417, Test Loss: 0.1832
# Epoch 98/200 | LR: 0.000640, Train Loss: 0.1426, Test Loss: 0.1847
# Epoch 99/200 | LR: 0.000640, Train Loss: 0.1436, Test Loss: 0.1785
# Epoch 100/200 | LR: 0.000640, Train Loss: 0.1428, Test Loss: 0.1834
# Epoch 101/200 | LR: 0.000640, Train Loss: 0.1447, Test Loss: 0.1807
# Epoch 102/200 | LR: 0.000640, Train Loss: 0.1412, Test Loss: 0.1854
# Epoch 103/200 | LR: 0.000640, Train Loss: 0.1423, Test Loss: 0.1819
# Epoch 104/200 | LR: 0.000640, Train Loss: 0.1438, Test Loss: 0.1791
# Epoch 105/200 | LR: 0.000640, Train Loss: 0.1432, Test Loss: 0.1765
# Epoch 106/200 | LR: 0.000640, Train Loss: 0.1428, Test Loss: 0.1786
# Epoch 107/200 | LR: 0.000640, Train Loss: 0.1388, Test Loss: 0.1829
# Epoch 108/200 | LR: 0.000640, Train Loss: 0.1396, Test Loss: 0.1800
# Epoch 109/200 | LR: 0.000640, Train Loss: 0.1382, Test Loss: 0.1812
# Epoch 110/200 | LR: 0.000640, Train Loss: 0.1401, Test Loss: 0.1799
# Epoch 111/200 | LR: 0.000640, Train Loss: 0.1362, Test Loss: 0.1832
# Epoch 112/200 | LR: 0.000640, Train Loss: 0.1377, Test Loss: 0.1787
# Epoch 113/200 | LR: 0.000640, Train Loss: 0.1387, Test Loss: 0.1813
# Epoch 114/200 | LR: 0.000640, Train Loss: 0.1398, Test Loss: 0.1773
# Epoch 115/200 | LR: 0.000640, Train Loss: 0.1378, Test Loss: 0.1783
# Epoch 116/200 | LR: 0.000640, Train Loss: 0.1383, Test Loss: 0.1815
# Epoch 117/200 | LR: 0.000640, Train Loss: 0.1356, Test Loss: 0.1788
# Epoch 118/200 | LR: 0.000640, Train Loss: 0.1342, Test Loss: 0.1782
# Epoch 119/200 | LR: 0.000640, Train Loss: 0.1340, Test Loss: 0.1807
# Epoch 120/200 | LR: 0.000512, Train Loss: 0.1361, Test Loss: 0.1761
# Epoch 121/200 | LR: 0.000512, Train Loss: 0.1337, Test Loss: 0.1825
# Epoch 122/200 | LR: 0.000512, Train Loss: 0.1355, Test Loss: 0.1766
# Epoch 123/200 | LR: 0.000512, Train Loss: 0.1381, Test Loss: 0.1739
# Epoch 124/200 | LR: 0.000512, Train Loss: 0.1362, Test Loss: 0.1791
# Epoch 125/200 | LR: 0.000512, Train Loss: 0.1355, Test Loss: 0.1767
# Epoch 126/200 | LR: 0.000512, Train Loss: 0.1362, Test Loss: 0.1795
# Epoch 127/200 | LR: 0.000512, Train Loss: 0.1359, Test Loss: 0.1720
# Epoch 128/200 | LR: 0.000512, Train Loss: 0.1330, Test Loss: 0.1812
# Epoch 129/200 | LR: 0.000512, Train Loss: 0.1357, Test Loss: 0.1751
# Epoch 130/200 | LR: 0.000512, Train Loss: 0.1356, Test Loss: 0.1794
# Epoch 131/200 | LR: 0.000512, Train Loss: 0.1344, Test Loss: 0.1727
# Epoch 132/200 | LR: 0.000512, Train Loss: 0.1343, Test Loss: 0.1749
# Epoch 133/200 | LR: 0.000512, Train Loss: 0.1356, Test Loss: 0.1719
# Epoch 134/200 | LR: 0.000512, Train Loss: 0.1331, Test Loss: 0.1751
# Epoch 135/200 | LR: 0.000512, Train Loss: 0.1336, Test Loss: 0.1755
# Epoch 136/200 | LR: 0.000512, Train Loss: 0.1319, Test Loss: 0.1705
# Epoch 137/200 | LR: 0.000512, Train Loss: 0.1325, Test Loss: 0.1808
# Epoch 138/200 | LR: 0.000512, Train Loss: 0.1323, Test Loss: 0.1701
# Epoch 139/200 | LR: 0.000512, Train Loss: 0.1344, Test Loss: 0.1776
# Epoch 140/200 | LR: 0.000512, Train Loss: 0.1325, Test Loss: 0.1719
# Epoch 141/200 | LR: 0.000512, Train Loss: 0.1350, Test Loss: 0.1766
# Epoch 142/200 | LR: 0.000512, Train Loss: 0.1326, Test Loss: 0.1852
# Epoch 143/200 | LR: 0.000512, Train Loss: 0.1335, Test Loss: 0.1728
# Epoch 144/200 | LR: 0.000512, Train Loss: 0.1330, Test Loss: 0.1778
# Epoch 145/200 | LR: 0.000512, Train Loss: 0.1317, Test Loss: 0.1693
# Epoch 146/200 | LR: 0.000512, Train Loss: 0.1312, Test Loss: 0.1700
# Epoch 147/200 | LR: 0.000512, Train Loss: 0.1305, Test Loss: 0.1749
# Epoch 148/200 | LR: 0.000512, Train Loss: 0.1306, Test Loss: 0.1711
# Epoch 149/200 | LR: 0.000512, Train Loss: 0.1297, Test Loss: 0.1746
# Epoch 150/200 | LR: 0.000512, Train Loss: 0.1297, Test Loss: 0.1705
# Epoch 151/200 | LR: 0.000512, Train Loss: 0.1290, Test Loss: 0.1690
# Epoch 152/200 | LR: 0.000512, Train Loss: 0.1299, Test Loss: 0.1750
# Epoch 153/200 | LR: 0.000512, Train Loss: 0.1285, Test Loss: 0.1706
# Epoch 154/200 | LR: 0.000512, Train Loss: 0.1292, Test Loss: 0.1721
# Epoch 155/200 | LR: 0.000512, Train Loss: 0.1274, Test Loss: 0.1767
# Epoch 156/200 | LR: 0.000512, Train Loss: 0.1292, Test Loss: 0.1738
# Epoch 157/200 | LR: 0.000512, Train Loss: 0.1297, Test Loss: 0.1749
# Epoch 158/200 | LR: 0.000512, Train Loss: 0.1268, Test Loss: 0.1689
# Epoch 159/200 | LR: 0.000512, Train Loss: 0.1284, Test Loss: 0.1738
# Epoch 160/200 | LR: 0.000410, Train Loss: 0.1293, Test Loss: 0.1762
# Epoch 161/200 | LR: 0.000410, Train Loss: 0.1275, Test Loss: 0.1722
# Epoch 162/200 | LR: 0.000410, Train Loss: 0.1261, Test Loss: 0.1749
# Epoch 163/200 | LR: 0.000410, Train Loss: 0.1276, Test Loss: 0.1676
# Epoch 164/200 | LR: 0.000410, Train Loss: 0.1268, Test Loss: 0.1675
# Epoch 165/200 | LR: 0.000410, Train Loss: 0.1270, Test Loss: 0.1737
# Epoch 166/200 | LR: 0.000410, Train Loss: 0.1275, Test Loss: 0.1723
# Epoch 167/200 | LR: 0.000410, Train Loss: 0.1283, Test Loss: 0.1757
# Epoch 168/200 | LR: 0.000410, Train Loss: 0.1265, Test Loss: 0.1706
# Epoch 169/200 | LR: 0.000410, Train Loss: 0.1250, Test Loss: 0.1681
# Epoch 170/200 | LR: 0.000410, Train Loss: 0.1278, Test Loss: 0.1733
# Epoch 171/200 | LR: 0.000410, Train Loss: 0.1250, Test Loss: 0.1742
# Epoch 172/200 | LR: 0.000410, Train Loss: 0.1265, Test Loss: 0.1776
# Epoch 173/200 | LR: 0.000410, Train Loss: 0.1271, Test Loss: 0.1716
# Epoch 174/200 | LR: 0.000410, Train Loss: 0.1270, Test Loss: 0.1692
# Epoch 175/200 | LR: 0.000410, Train Loss: 0.1255, Test Loss: 0.1732
# Epoch 176/200 | LR: 0.000410, Train Loss: 0.1255, Test Loss: 0.1732
# Epoch 177/200 | LR: 0.000410, Train Loss: 0.1240, Test Loss: 0.1741
# Epoch 178/200 | LR: 0.000410, Train Loss: 0.1261, Test Loss: 0.1725
# Epoch 179/200 | LR: 0.000410, Train Loss: 0.1231, Test Loss: 0.1698
# Epoch 180/200 | LR: 0.000410, Train Loss: 0.1227, Test Loss: 0.1699
# Epoch 181/200 | LR: 0.000410, Train Loss: 0.1243, Test Loss: 0.1719
# Epoch 182/200 | LR: 0.000410, Train Loss: 0.1216, Test Loss: 0.1749
# Epoch 183/200 | LR: 0.000410, Train Loss: 0.1253, Test Loss: 0.1723
#
# #***# Early stopping triggered after 184 epochs!

# %%
model.test()
# Out:
# Test Loss: 0.1675

# %%
model.plot_training_curves()

# %%
output_feature_name = ['NEE','RECO']
model.get_R2_score(y_scaler, output_feature_name)
# Out:
# Feature NEE R2 Score is: 0.9392414589841256
# Feature RECO R2 Score is: 0.9034888703226529

# %%
model.Vis_plot_prediction_result_time_series(y_scaler, output_feature_name, site=0, year=0)

# %%
model.Vis_scatter_prediction_result(y_scaler, output_feature_name)
